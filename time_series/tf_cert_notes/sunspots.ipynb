# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
# Avaliable at: https://www.kaggle.com/c/sunspots/data
df = pd.read_csv('./Sunspots.csv', parse_dates=["Date"], index_col="Date")
series = df["Monthly Mean Total Sunspot Number"].asfreq("1M")
series.head()
# Out:
# Date
# 1749-01-31     96.7
# 1749-02-28    104.3
# 1749-03-31    116.7
# 1749-04-30     92.8
# 1749-05-31    141.7
# Freq: M, Name: Monthly Mean Total Sunspot Number, dtype: float64

# %%
series.plot(figsize=(12, 5))
plt.show()

# %%
series["1995-01-01":].plot()
plt.show()

# %%
# Naive approach to forecast the next value
series.diff(1).plot()
plt.axis([0, 100, -50, 50])
# Out:
# (0.0, 100.0, -50.0, 50.0)
